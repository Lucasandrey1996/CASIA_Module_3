-- %%
SELECT a.StateProvince, COUNT(oh.SalesOrderID) AS OrderCount
FROM bronze.Address a
JOIN bronze.SalesOrderHeader oh ON a.AddressID = oh.BillToAddressID
GROUP BY a.StateProvince
ORDER BY a.StateProvince;
